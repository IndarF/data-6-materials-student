# %%
import numpy as np

# %% [markdown]
# # Discussion 01 - SPRK 010
#
# ### Question 2
# In this question, we look at 3 different problems:
# - (5 + 7) * min(3,4)
# - abs(max(5,2) - min(7,10)
# - max(abs(5 - 12 // 2), min(3,4), 2 ** 3)
#
# We want to see what the output will be for each of these problems.

# %%
(5 + 7) * min(3,4)

# %%
abs(max(5,2) - min(7,10)

# %%
max(abs(5 - 12 // 2), min(3,4), 2 ** 3)
